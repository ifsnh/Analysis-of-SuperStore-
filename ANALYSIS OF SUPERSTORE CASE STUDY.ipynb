# %% [markdown]
# ## N.HARISH
#  ### DataAnalytics Intern From EDUNET FOUNDATION

# %% [markdown]
# ## CASE STUDY : ANALYSIS OF SUPERSTORE

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_orders = pd.read_csv(r"C:\Users\nhifs\OneDrive\Desktop\Superstore Analysis\SampleSuperstore.csv")
print("Data read Successfully")
# Out:
# Data read Successfully

# %%
d = pd.read_csv("SampleSuperstore.csv")

# %%
d
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### Exploratory DATA ANALYSIS

# %% [markdown]
# #### TYPES OF DATA'S AVAILABLE IN COLUMN'S

# %%
d['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
d['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
d['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
d['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
d['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
d['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
d['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %% [markdown]
# ###### TO Check NULL Values

# %%
d.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ##### NO OF UNIQUE Values in EACH & EVERY Column

# %%
df_orders.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ###### STASTICAL DATA OF A DATASET

# %%
df_orders.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
##DATA TYPES
df_orders.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
###UNIQUE DATA IN EACH & EVERY Column
for col in df_orders:
    print(df_orders[col].unique())
# Out:
# ['Second Class' 'Standard Class' 'First Class' 'Same Day']
# ['Consumer' 'Corporate' 'Home Office']
# ['United States']
# ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
#  'Fairfield' 'Grand Prairie' 'Redlands' 'Hamilton' 'Westfield' 'Akron'
#  'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit'
#  'Tampa' 'Santa Clara' 'Lakeville' 'San Diego' 'Brentwood' 'Chapel Hill'
# ...

# %%
### NUMBER OF DUPLICATE VALUES
df_orders.duplicated().sum()
# Out:
# 17

# %%
import os

# %%
### SUMMARY OF DATA
df_orders.value_counts()
# Out:
# Ship Mode       Segment      Country        City           State       Postal Code  Region   Category         Sub-Category  Sales    Quantity  Discount  Profit
# Standard Class  Consumer     United States  Salem          Oregon      97301        West     Office Supplies  Paper         10.368   2         0.2        3.6288      2
# Second Class    Corporate    United States  Chicago        Illinois    60653        Central  Office Supplies  Binders       3.564    3         0.8       -6.2370      2
# Standard Class  Consumer     United States  San Francisco  California  94122        West     Office Supplies  Paper         12.840   3         0.0        5.7780      2
#                                             Los Angeles    California  90036        West     Office Supplies  Paper         19.440   3         0.0        9.3312      2
# ...

# %% [markdown]
# #                    Visualization Of a DataSet

# %%
## ANALYSIS Of Sub-Category
plt.figure(figsize=(12,10))
df_orders['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
### FREQUENCY OF CATEGORY & SUB-CATEGORY
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=df_orders)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ####### HERE Furniture Category item is VERY LESS like chairs,bookcase etc.
# ####### Office supplies are MEDIUM like labelss,art etc.
# ####### Technology frequency are HIGH i.e phones,machines etc.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title("Count of orders in Total dataset")
x = sns.countplot(data = d, x = 'Category',palette = "light:b")
for i in x.containers:
    x.bar_label(i,)

# %% [markdown]
# ### PROFIT & LOSS DATA SET'S of Region's & Discount's

# %%
loss = d[d['Profit']<0]
profit = d[d['Profit']>0]

# %%
profit
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5     Standard Class   Consumer  United States      Los Angeles  California
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
a = profit['Profit'].mean()
b = profit['Profit'].sum()
c = profit['Discount'].mean()
print("The average profit in profit dataset is {} and total profit is {}".format(a,b))
print("The average discount is {}".format(c*100))
# Out:
# The average profit in profit dataset is 54.91788376768429 and total profit is 442528.3074
# The average discount is 8.104368329610324

# %%
loss
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9920  Standard Class    Corporate  United States            Bryan
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# ...

# %%
a = loss['Profit'].mean()
b = loss['Profit'].sum()
c = loss['Discount'].mean()
print("The average profit in loss dataset is {} and total profit is {}".format(a,b))
print("The average discount is {}".format(c*100))
# Out:
# The average profit in loss dataset is -83.44804152859435 and total profit is -156131.2857
# The average discount is 48.088722608230896

# %%
x = sns.countplot(data = loss, x = 'Region')
for i in x.containers:
    x.bar_label(i,)

# %%
plt.figure(figsize=(15,4))
plt.subplots_adjust(wspace=0.33)
plt.subplot(1,3,1)
plt.title('Total loss by region')
x = sns.barplot(data = loss, x= 'Region',y='Profit',estimator=np.sum,palette = "light:#5A9")
for i in x.containers:
    x.bar_label(i,)
plt.subplot(1,3,2)
plt.title('Average loss by region')
y = sns.barplot(data = loss, x= 'Region',y='Profit', palette = "flare")
for i in y.containers:
    y.bar_label(i,)

# %%
gdsloss = loss.groupby(["Region","State"]).agg({'Sales': 'sum', 'Profit': 'sum','Discount': 'mean'})
print(gdsloss)
# Out:
#                               Sales      Profit  Discount
# Region  State
# Central Illinois         38626.2020 -19501.6975  0.564314
#         Texas           102656.4568 -36813.1875  0.541646
# East    Connecticut        252.3570    -19.6146  0.300000
#         Delaware           510.2790    -85.8963  0.300000
#         Maryland           789.8030    -71.1170  0.300000
#         Massachusetts     3275.3210   -566.2617  0.300000
#         New Hampshire     1053.1640   -105.3164  0.300000
#         New Jersey         418.2920    -51.2906  0.300000
#         New York         26533.3500  -5031.1378  0.310638
#         Ohio             49807.6240 -21750.0002  0.472249
#         Pennsylvania     75792.2320 -21602.8515  0.460791
#         Rhode Island      1758.2460   -230.1678  0.300000
#         West Virginia      673.3440    -76.9536  0.300000
# South   Florida          45694.1320  -8689.8295  0.501984
#         North Carolina   28226.5400 -11557.9854  0.505882
# ...

# %%
sns.lineplot(data = gdsloss, x = "Discount", y = 'Profit', color= "b",marker = "p")
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
plt.figure(figsize=(30,10))
sns.lineplot(data = gdsloss, x = "State", y = "Profit", marker= ".", dashes=True,color="r",ms =20)
# Out:
# <Axes: xlabel='State', ylabel='Profit'>

# %%
fig, ax = plt.subplots()
ax= sns.lineplot(x= 'Discount', y='Profit', data=loss, color="r", legend = True)
ax= sns.lineplot(x= 'Discount', y='Profit', data=profit, color="g", legend = True)

# %%
fig, axes = plt.subplots(2,3,figsize=(25,20))
axes[0,0].set_title("Total Data on Profit")
x = sns.barplot(data=d, x='Ship Mode', y = 'Profit',hue = "Region", estimator = np.sum, ax=axes[0,0])
for i in x.containers:
    x.bar_label(i,)
axes[0,1].set_title("Loss Data on Profit")
y = sns.barplot(data=d, x='Ship Mode', y = 'Profit',hue = "Region", estimator = np.sum, ax=axes[0,1])
for i in y.containers:
    y.bar_label(i,)
axes[0,2].set_title("Profit Data on Profit")
z = sns.barplot(data=d, x='Ship Mode', y = 'Profit',hue = "Region", estimator = np.sum, ax=axes[0,2])
for i in z.containers:
    z.bar_label(i,)
axes[1,0].set_title("Total Data on Discount")
x = sns.barplot(data=d, x='Ship Mode', y = 'Discount',hue = "Region", estimator = np.mean, ax=axes[1,0])
for i in x.containers:
    x.bar_label(i,)
axes[1,1].set_title("Loss Data on Discount")
y = sns.barplot(data=d, x='Ship Mode', y = 'Discount',hue = "Region", estimator = np.mean, ax=axes[1,1])
for i in y.containers:
    y.bar_label(i,)
axes[1,2].set_title("Profit Data on Discount")
z = sns.barplot(data=d, x='Ship Mode', y = 'Discount',hue = "Region", estimator = np.mean, ax=axes[1,2])
for i in z.containers:
    z.bar_label(i,)

# %%
df_orders.plot(kind='box', subplots=True, layout=(3,2), sharex=False, sharey=False)
plt.rcParams['figure.figsize'] = [14,12]
plt.show()

# %%
# COUNT PLOT OF SEGMENT
sns.countplot(x=df_orders['Segment'])
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %% [markdown]
# ##### SALES & PROFIT

# %%
 fig,ax = plt.subplots(figsize = (10 , 6))  
ax.scatter(df_orders["Sales"] , df_orders["Profit"])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
plt.show()

# %% [markdown]
# #### CONCLUSION

# %% [markdown]
# ** All regions are experiencing losses.
# ** Central and East regions have high Discounts.
# ** losses are high in Central region.
# ** PROFIT is less in South & Central.
# ** TOTAL sum of Profitsnin Sales is Negative.
# ** Technology Segment is Profitable.

# %% [markdown]
# # THANK  U FOR THIS OPPORTUNITY
